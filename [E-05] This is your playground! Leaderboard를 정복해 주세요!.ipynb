# %% [markdown]
# # 5-13. 프로젝트 : This is your playground! Leaderboard를 정복해 주세요!
#
# 자, 이제 여러분이 직접 다양한 하이퍼 파라미터를 튜닝하며 최적의 조합을 찾아볼 차례입니다.
#
# 여기서 잠깐, 물론 캐글에서의 성적 또는 모델의 성능을 최대화 하기 위한 방법에는 하이퍼 파라미터 튜닝만 있는 것은 절대 아닙니다.
# 앞선 과정에서 배웠거나 앞으로 배울 내용에서도 다루듯 모델의 성능을 최적화하는 방법은 매우 많고 지금도 끊임없이 연구되고 있습니다.
#
# 예를 들면 가장 기본적으로는 데이터를 깊게 탐색하는 EDA 과정을 통해 불필요한 피처를 골라내거나 적절하게 피처를 수정하는 등의 피처 엔지니어링을 진행함으로써 데이터를 정제하는 것이 매우 중요합니다. 데이터가 무엇이냐에 따라, 그리고 그 데이터를 어떻게 정제하느냐에 따라 모델의 파라미터를 튜닝하는 것만으로는 절대 얻을 수 없는 성능 향상이 이루어질 수 있습니다.
#
# 오늘은 이렇게 다양한 방법론 중 하이퍼 파라미터 튜닝에 집중해서 모델의 성능을 최대한 끌어올려보지만, 튜닝은 최적화 방법 중 하나일 뿐이라는 것을 잊지 마세요!
#
# <br>
#
# **✓ 튜닝해볼 수 있는 모델 클래스 인자**
#
# 대표적으로 자주 튜닝하는 ***lightgbm 라이브러리의 인자***는 다음과 같습니다.
#
# - `max_depth` : 의사 결정 나무의 깊이, 정수 사용
# - `learning_rate` : 한 스텝에 이동하는 양을 결정하는 파라미터, 보통 0.0001~0.1 사이의 실수 사용
# - `n_estimators` : 사용하는 개별 모델의 개수, 보통 50~100 이상의 정수 사용
# - `num_leaves` : 하나의 LightGBM 트리가 가질 수 있는 최대 잎의 수
# - `boosting_type` : 부스팅 방식, gbdt, rf 등의 문자열 입력
#
# 위에서 저는 `n_estimators`와 `max_depth` 에 대해서만 아주 간단하게 실험했지만, 훨씬 더 다양하게 실험을 하며 최적의 조합을 찾아볼 수 있습니다.
# 실제로 lightgbm에 넣을 수 있는 인자는 아래 자료들에서 설명하는 것처럼 매우 다양합니다.
#
# - [lightGBM / XGBoost 파라미터 설명](http://machinelearningkorea.com/2019/09/29/lightgbm-%ED%8C%8C%EB%9D%BC%EB%AF%B8%ED%84%B0/)
# - [Chapter 4. 분류 - LightGBM](https://injo.tistory.com/48)
#
# 위의 자료 외에도 `lightgbm`, `xgboost` 하이퍼 파라미터 튜닝 키워드로 검색해보면 다양한 하이퍼 파라미터의 종류를 확인할 수 있습니다.
#
# 실험 과정에서는 물론 위에서 만들었던 `my_GridSearch()`, `save_submission()` 등의 함수를 사용해도 되고, 혹은 여러분이 원하는 새로운 함수를 만들어서 사용해도 됩니다!

# %% [markdown]
# **✓ 시도해볼 수 있는 방법**
#
# 여러분이 시도해볼 수 있는 방법은 다음과 같은 것들이 있습니다.
#
# - 기존에 있는 데이터의 피처를 모델을 보다 잘 표현할 수 있는 형태로 처리하기 (피처 엔지니어링)
# - LGBMRegressor, XGBRegressor, RandomForestRegressor 세 가지 이상의 다양한 모델에 대해 하이퍼 파라미터 튜닝하기
# - 다양한 하이퍼 파라미터에 대해 그리드 탐색을 시도해서 최적의 조합을 찾아보기
# - Baseline 커널에서 활용했던 블렌딩 방법 활용하기
#
# 물론 이 외에도 좋은 아이디어가 있다면 당연히 시도해보는 것도 좋습니다. 자유롭게 여러 가지 방법을 활용해서 점수를 끌어올려 보세요!
# 참고로, 진행하면서 도움이 될 수 있는 가장 좋은 자료는 이미 대회를 진행한 사람들이 올려둔 커널입니다.
#
# - https://www.kaggle.com/c/2019-2nd-ml-month-with-kakr/notebooks
#
# 아주 다양하게 데이터를 탐색해 본 커널도 있고, 상위권을 달성한 커널은 오늘 다루지 않은 스태킹 앙상블(stacking ensemble) 등의 기법을 활용한 커널을 활용하기도 합니다. 한 번씩 구경해보고 다른 사람들은 어떤 전략으로 성능을 끌어올렸는지 공부해보는 것도 매우 좋을 겁니다!
#
# 여러 가지 실험을 해보고 결과 csv는 캐글에, 사용한 노트북은 깃허브(GitHub)를 통해 이곳에 제출해 주세요. 제출한 노트북에는 본인의 캐글 Submission 스코어를 기재해 주시기 바랍니다.
#
# 그럼, 시작해보죠! 화이팅!!! 💪🏼

# %% [markdown]
# **프로젝트 루브릭**
#
# - 데이터 전처리, 모델학습, 예측의 전체 과정을 거쳐 캐글 submission까지 전과정이 성공적으로 진행되었는가?
# - 제출된 노트북이 캐글 커널로 사용될 수 있을 만큼 전처리, 학습, 최적화 진행 과정이 체계적으로 기술되었는가?
# - 다양한 피처 엔지니어링과 하이퍼 파라미터 튜닝 등의 최적화 기법을 통해 캐글 리더보드의 Private score 기준 110000 이하의 점수를 얻었는가?

# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler ,RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder


import missingno as msno

from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from datetime import datetime as dt

np.random.seed(111)

# %%
data_dir = '/content/drive/MyDrive/아이펠/풀잎스쿨/data/kaggle-kakr-housing-data'

train_data_path = join(data_dir, 'train.csv')
test_data_path = join(data_dir, 'test.csv')

train = pd.read_csv(train_data_path)
test = pd.read_csv(test_data_path)

# %% [markdown]
# ## 1. 데이터 살펴보기
#
# >1. ID : 집을 구분하는 번호
# 2. date : 집을 구매한 날짜
# 3. price : 타겟 변수인 집의 가격
# 4. bedrooms : 침실의 수
# 5. bathrooms : 침실당 화장실 개수
# 6. sqft_living : 주거 공간의 평방 피트
# 7. sqft_lot : 부지의 평방 피트
# 8. floors : 집의 층수
# 9. waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
# 10. view : 집이 얼마나 좋아 보이는지의 정도
# 11. condition : 집의 전반적인 상태
# 12. grade : King County grading 시스템 기준으로 매긴 집의 등급
# 13. sqft_above : 지하실을 제외한 평방 피트
# 14. sqft_basement : 지하실의 평방 피트
# 15. yr_built : 집을 지은 년도
# 16. yr_renovated : 집을 재건축한 년도
# 17. zipcode : 우편번호
# 18. lat : 위도
# 19. long : 경도
# 20. sqft_living15 : 2015년 기준 주거 공간의 평방 피트(집을 재건축했다면, 변화가 있을 수 있음)
# 21. sqft_lot15 : 2015년 기준 부지의 평방 피트(집을 재건축했다면, 변화가 있을 수 있음)

# %%
# training, test set 차원 확인
print('train data dim : {}'.format(train.shape))
print('test data dim : {}'.format(test.shape))
# Out:
# train data dim : (15035, 21)
# test data dim : (6468, 20)

# %%
# train, test set 합치기
# train_len을 변수로 저장해 두었다가, 다시 분할할 때 사용
train_len = len(train)
data = pd.concat((train, test), axis=0)

# %%
data
# Out:
#          id             date     price  ...     long  sqft_living15  sqft_lot15
# 0         0  20141013T000000  221900.0  ... -122.257           1340        5650
# 1         1  20150225T000000  180000.0  ... -122.233           2720        8062
# 2         2  20150218T000000  510000.0  ... -122.045           1800        7503
# 3         3  20140627T000000  257500.0  ... -122.327           2238        6819
# 4         4  20150115T000000  291850.0  ... -122.315           1650        9711
# ...     ...              ...       ...  ...      ...            ...         ...
# 6463  21498  20140626T000000       NaN  ... -122.002           1320       11303
# 6464  21499  20150126T000000       NaN  ... -122.288           1400        1230
# 6465  21500  20150219T000000       NaN  ... -122.409           1330        1265
# 6466  21501  20140623T000000       NaN  ... -122.299           1020        2007
# 6467  21502  20150116T000000       NaN  ... -122.069           1410        1287
#
# ...

# %% [markdown]
# **['price']에서 결측치가 확인됨**
#
# <u>다른 결측치는 없는지 확인</u>

# %% [markdown]
# ### 1) 결측치 제거

# %%
msno.matrix(data)

# %%
# 1. ['price'] 컬럼이 결측치인지 확인합니다.
null_check = pd.isnull(data['price'])
print(null_check)
print(data.head())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6463     True
# 6464     True
# 6465     True
# 6466     True
# 6467     True
# Name: price, Length: 21503, dtype: bool
#    id             date     price  ...     long  sqft_living15  sqft_lot15
# 0   0  20141013T000000  221900.0  ... -122.257           1340        5650
# 1   1  20150225T000000  180000.0  ... -122.233           2720        8062
# 2   2  20150218T000000  510000.0  ... -122.045           1800        7503
# 3   3  20140627T000000  257500.0  ... -122.327           2238        6819
# 4   4  20150115T000000  291850.0  ... -122.315           1650        9711
#
# [5 rows x 21 columns]

# %%
# 2. 결측치인 데이터만 뽑아냅니다.
# df.loc[행 인덱스, 열 인덱스]
# 불리언 시리즈를 행 인덱스로 사용할 수 있다.(null_check의 경우)
null_data = data.loc[null_check, 'price']
null_data.head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: price, dtype: float64

# %%
# 3. 결측치인 데이터의 개수를 셉니다.
print('{}: {}'.format('price', len(null_data.values)))
# Out:
# price: 6468

# %% [markdown]
# - `['price']`의 결측치는 test데이터셋의 부분이었다... (예리한척 실패..)
# - 그냥 train, test데이터 셋을 나눠서 데이터를 보기로 결정

# %%
train = pd.read_csv(train_data_path)
test = pd.read_csv(test_data_path)

# %%
# train 데이터셋에서 결측치가 있는지 다시 확인
msno.matrix(train)

# %% [markdown]
# - 예제에서는 `date` 칼럼을 삭제했는데, `date`를 int로 변환시켜서 모델에 넣을 수 있는 `feature`로 만들어준다.

# %%
# DataFrame.astype(int) : 문자열을 정수타입으로 바꿔준다.
# pd.to_numeric() : 메소드를 이용한 문자열 칼럼의 숫자형 변환

train['date'] = train['date'].apply(lambda i: i[:6]).astype(int)
train.head()
# Out:
#    id    date     price  bedrooms  ...      lat     long  sqft_living15  sqft_lot15
# 0   0  201410  221900.0         3  ...  47.5112 -122.257           1340        5650
# 1   1  201502  180000.0         2  ...  47.7379 -122.233           2720        8062
# 2   2  201502  510000.0         3  ...  47.6168 -122.045           1800        7503
# 3   3  201406  257500.0         3  ...  47.3097 -122.327           2238        6819
# 4   4  201501  291850.0         3  ...  47.4095 -122.315           1650        9711
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2) y라벨 데이터 확인하기
# - 라벨값인 `train['price']`의 분포를 확인한다.
# - log 변환한다.
# - 나중에 다시 `np.exp1m()`을 활용해서 되돌려야 됨

# %%
# y 분포확인하기
y=train['price']
sns.kdeplot(y)
plt.show()

# %%
# 로그변환하기 => 나중에 모델이 값을 예측한 후에 다시 np.exp1m()을 활용해서 되돌려야 됨
y = np.log1p(y)
sns.kdeplot(y)
plt.show()

# %% [markdown]
# ### 3) 상관계수 확인
# - 0.05 이하의 관계가 나온 4개의 컬럼을 삭제

# %%
# price와 다른 컬럼들 간의 상관계수 확인
pd.DataFrame(train.corr()['price'])
# Out:
#                   price
# id             0.020899
# date           0.007717
# price          1.000000
# bedrooms       0.323672
# bathrooms      0.525479
# sqft_living    0.702899
# sqft_lot       0.096793
# floors         0.262588
# waterfront     0.265738
# view           0.400806
# condition      0.039740
# grade          0.667211
# sqft_above     0.608577
# sqft_basement  0.322218
# yr_built       0.047290
# yr_renovated   0.140808
# zipcode       -0.051498
# lat            0.301604
# long           0.023547
# sqft_living15  0.586419
# sqft_lot15     0.086384

# %%
# 상관계수가 0.05이하인 컬럼명을 추린다.
low = train.corr().index[(train.corr()['price'] < 0.05)]
low
# Out:
# Index(['id', 'date', 'condition', 'yr_built', 'zipcode', 'long'], dtype='object')

# %% [markdown]
# 위의 상관계수 표를 보고 0.05 이하의 관계가 나온 4개의 칼럼을 삭제한다.

# %%
train.drop(train[low], axis=1, inplace=True)
train
# Out:
#            price  bedrooms  bathrooms  ...      lat  sqft_living15  sqft_lot15
# 0       221900.0         3       1.00  ...  47.5112           1340        5650
# 1       180000.0         2       1.00  ...  47.7379           2720        8062
# 2       510000.0         3       2.00  ...  47.6168           1800        7503
# 3       257500.0         3       2.25  ...  47.3097           2238        6819
# 4       291850.0         3       1.50  ...  47.4095           1650        9711
# ...          ...       ...        ...  ...      ...            ...         ...
# 15030   610685.0         4       2.50  ...  47.5137           2520        6023
# 15031  1007500.0         4       3.50  ...  47.5537           2050        6200
# 15032   360000.0         3       2.50  ...  47.6993           1530        1509
# 15033   400000.0         4       2.50  ...  47.5107           1830        7200
# 15034   325000.0         2       0.75  ...  47.5941           1020        1357
#
# ...

# %%
# test 데이터 셋에서도 삭제해준다.
# 단, 삭제하기 전에 test의 id 시리즈가 필요하므로 변수로 저장해 둔다.
test_id = test['id']
test.drop(test[low], axis=1, inplace=True)
test
# Out:
#       bedrooms  bathrooms  sqft_living  ...      lat  sqft_living15  sqft_lot15
# 0            3       2.25         2570  ...  47.7210           1690        7639
# 1            4       3.00         1960  ...  47.5208           1360        5000
# 2            4       4.50         5420  ...  47.6561           4760      101930
# 3            3       1.00         1780  ...  47.5123           1780        8113
# 4            3       2.50         1890  ...  47.3684           2390        7570
# ...        ...        ...          ...  ...      ...            ...         ...
# 6463         3       1.75         1500  ...  47.3095           1320       11303
# 6464         3       2.00         1490  ...  47.5699           1400        1230
# 6465         3       2.50         1310  ...  47.5773           1330        1265
# 6466         2       0.75         1020  ...  47.5944           1020        2007
# 6467         3       2.50         1600  ...  47.5345           1410        1287
#
# ...

# %% [markdown]
# ### 4) 이상치 제거
#
# ***수치형 변수 데이터 이상치를 제거함***
#
# - IQR 방식으로 이상치를 제거
#
#     ![](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FboDTe4%2FbtqHP3beJxg%2F8mzOK0wWK31QXpaY7VDJRk%2Fimg.png)

# %%
# 이상치 제거하는 함수
def get_outlier(df=None, column=None, weight=1.5):
  # target 값과 상관관계가 높은 열을 우선적으로 진행
  quantile_25 = np.percentile(df[column].values, 25)
  quantile_75 = np.percentile(df[column].values, 75)

  IQR = quantile_75 - quantile_25
  IQR_weight = IQR*weight
  
  lowest = quantile_25 - IQR_weight
  highest = quantile_75 + IQR_weight
  
  outlier_idx = df[column][ (df[column] < lowest) | (df[column] > highest) ].index
  return outlier_idx

# %% [markdown]
# 1. sqft_living :주거 공간의 평방 피트
# - 수치형 데이터 (회귀 그래프)
# - 이상치 확인 후 제거

# %%
sns.regplot(x='sqft_living', y='price', data=train)

# %%
# 함수 사용해서 이상치 값 삭제
outlier_idx = get_outlier(df=train, column='sqft_living', weight=1.5)
train.drop(outlier_idx, axis=0, inplace=True)

# %%
# 이상치가 제거된 회귀 그래프
sns.regplot(x='sqft_living', y='price', data=train)

# %% [markdown]
# 2. sqft_lot : 부지의 평방 피트
# - 수치형 데이터 (회귀 그래프)
# - 이상치 확인 후 제거

# %%
sns.regplot(x='sqft_lot', y='price', data=train)

# %%
# 함수 사용해서 이상치 값 삭제
outlier_idx = get_outlier(df=train, column='sqft_lot', weight=1.5)
train.drop(outlier_idx, axis=0, inplace=True)

# %%
# 이상치가 제거된 회귀 그래프
sns.regplot(x='sqft_lot', y='price', data=train)

# %% [markdown]
# 3. sqft_above : 지하실을 제외한 평방 피트
# - 수치형 데이터 (회귀 그래프)
# - 이상치 확인 후 제거

# %%
sns.regplot(x='sqft_above', y='price', data=train)

# %% [markdown]
# - 이상치가 딱히 발견되지 않아서 제거하지 않음

# %% [markdown]
# 4. lat : 위도
# - 수치형 데이터 (회귀 그래프)
# - 이상치 확인 후 제거

# %%
sns.regplot(x='lat', y='price', data=train)

# %%
# 함수 사용해서 이상치 값 삭제
outlier_idx = get_outlier(df=train, column='lat', weight=1.5)
train.drop(outlier_idx, axis=0, inplace=True)

# %%
# 이상치가 제거된 회귀 그래프
sns.regplot(x='sqft_lot', y='price', data=train)

# %% [markdown]
# 5. sqft_living15 : 2015년 기준 주거 공간의 평방 피트(집을 재건축했다면, 변화가 있을 수 있음)
# - 수치형 데이터(회귀 그래프)
# - 이상치 확인 후 제거

# %%
sns.regplot(x='sqft_living15', y='price', data=train)

# %%
# 함수 사용해서 이상치 값 삭제
outlier_idx = get_outlier(df=train, column='sqft_living15', weight=1.5)
train.drop(outlier_idx, axis=0, inplace=True)

# %%
# 이상치가 제거된 회귀 그래프
sns.regplot(x='sqft_living15', y='price', data=train)

# %% [markdown]
# - 마지막으로 train데이터 셋의 info()를 확인

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12775 entries, 0 to 15034
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          12775 non-null  float64
#  1   bedrooms       12775 non-null  int64
#  2   bathrooms      12775 non-null  float64
#  3   sqft_living    12775 non-null  int64
#  4   sqft_lot       12775 non-null  int64
#  5   floors         12775 non-null  float64
#  6   waterfront     12775 non-null  int64
#  7   view           12775 non-null  int64
#  8   grade          12775 non-null  int64
#  9   sqft_above     12775 non-null  int64
#  10  sqft_basement  12775 non-null  int64
#  11  yr_renovated   12775 non-null  int64
#  12  lat            12775 non-null  float64
#  13  sqft_living15  12775 non-null  int64
#  14  sqft_lot15     12775 non-null  int64
# dtypes: float64(4), int64(11)
# memory usage: 1.6 MB

# %% [markdown]
# ### 5) 데이터 shape 확인
# - 마지막으로 학습데이터의 입력값인 `train`, 학습데이터의 라벨값인 `y`, 테스트 데이터의 입력값인 `test`의 갯수가 잘 맞는지 확인

# %%
train.head()
# Out:
#       price  bedrooms  bathrooms  ...      lat  sqft_living15  sqft_lot15
# 0  221900.0         3       1.00  ...  47.5112           1340        5650
# 1  180000.0         2       1.00  ...  47.7379           2720        8062
# 2  510000.0         3       2.00  ...  47.6168           1800        7503
# 3  257500.0         3       2.25  ...  47.3097           2238        6819
# 4  291850.0         3       1.50  ...  47.4095           1650        9711
#
# [5 rows x 15 columns]

# %% [markdown]
# - train데이터에서 x와 y값이 나눠지지 않았으므로, 나누어 준다.

# %%
y = train['price']
y = np.log1p(y)
train.drop(['price'], axis=1, inplace=True)

# %%
print(train.shape)
print(y.shape)
print(test.shape)
# Out:
# (12775, 14)
# (12775,)
# (6468, 14)

# %% [markdown]
# - train데이터 : 입력값과 라벨값의 갯수가 일치함
# - train 입력값과 test 입력값의 컬럼수가 일치함

# %% [markdown]
# ## RMSE 계산
# 먼저 필요한 라이브러리를 가져오겠습니다.
# 데이터셋을 훈련 데이터셋과 검증 데이터셋으로 나누기 위한 `train_test_split` 함수와, RMSE 점수를 계산하기 위한 `mean_squared_error`를 가져옵니다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# 대회에서 점수를 매기는 것과 같은 평가 척도인 RMSE를 계산하기 위해 다음과 같은 함수를 만들어놓겠습니다.
# 한 가지 주의해야 할 것은, `y_test`나 `y_pred`는 위에서 `np.log1p()`로 변환이 된 값이기 때문에 <u>원래 데이터의 단위에 맞게 되돌리기 위해 `np.expm1()`</u>을 추가해야 한다는 점입니다.
#
# exp로 다시 변환해서 mean_squared_error를 계산한 값에 np.sqrt를 취하면 RMSE 값을 얻을 수 있겠죠!

# %%
def rmse(y_test, y_pred):
    return np.sqrt(mean_squared_error(np.expm1(y_test), np.expm1(y_pred)))

# %% [markdown]
# ## 모델링

# %%
# 필요한 라이브러리 임포트하기
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
random_state=2022

gboost = GradientBoostingRegressor(random_state=random_state)
xgboost = xgb.XGBRegressor(random_state=random_state)
lightgbm = lgb.LGBMRegressor(random_state=random_state)
randomforest = RandomForestRegressor(random_state=random_state)
histgradient = HistGradientBoostingRegressor(random_state=random_state)

models = [gboost, xgboost, lightgbm, randomforest, histgradient]

# %%
def get_scores(models, train, y):
    # 답안 작성
    df = {}
    
    for model in models:
        model_name = model.__class__.__name__
        
        X_train, X_test, y_train, y_test = train_test_split(train, y, random_state=random_state, test_size=0.2)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        df[model_name] = rmse(y_test, y_pred)
        score_df = pd.DataFrame(df, index=['RMSE']).T.sort_values('RMSE', ascending=False)
            
    return score_df

get_scores(models, train, y)
# Out:
# [12:19:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                                         RMSE
# GradientBoostingRegressor      108397.699775
# XGBRegressor                   107710.248314
# RandomForestRegressor          105069.266316
# HistGradientBoostingRegressor  102958.885626
# LGBMRegressor                  101871.477863

# %% [markdown]
# ## 그리드 탐색

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# `GridSearchCV`에 입력되는 인자들은 다음과 같습니다.
#
# - `param_grid` : 탐색할 파라미터의 종류 (딕셔너리로 입력)
# - `scoring` : 모델의 성능을 평가할 지표
# - `cv` : cross validation을 수행하기 위해 train 데이터셋을 나누는 조각의 개수
# - `verbose` : 그리드 탐색을 진행하면서 진행 과정을 출력해서 보여줄 메세지의 양 (숫자가 클수록 더 많은 메세지를 출력합니다.)
# - `n_jobs` : 그리드 탐색을 진행하면서 사용할 CPU의 개수

# %%
param_grid = {
    'n_estimators': [20, 50],
    'max_depth': [1, 5],
}

# %%
def my_GridSearch(model, train, y, param_grid, verbose=2, n_jobs=5):
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(model, param_grid=param_grid, scoring='neg_mean_squared_error', \
                              cv=10, verbose=verbose, n_jobs=n_jobs)
    
    # 모델 fitting
    grid_model.fit(train, y)

    # 결과값 저장
    params = grid_model.cv_results_['params']
    score = grid_model.cv_results_['mean_test_score']
    
    # 데이터 프레임 생성
    results = pd.DataFrame(params)
    results['score'] = score
    
    # RMSLE 값 계산 후 정렬
    results['RMSLE'] = np.sqrt(-1 * results['score'])
    results = results.sort_values('RMSLE')

    return results

# %% [markdown]
# ### 1. GradientBoostingRegressor

# %%
model_1 = GradientBoostingRegressor(random_state=random_state)

# %%
my_GridSearch(model_1, train, y, param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
#    max_depth  n_estimators     score     RMSLE
# 3          5            50 -0.036728  0.191645
# 2          5            20 -0.045049  0.212248
# 1          1            50 -0.063255  0.251506
# 0          1            20 -0.097573  0.312366

# %%
model_1 = GradientBoostingRegressor(max_depth=5, n_estimators=50, random_state=random_state)

# %%
def save_submission(model, train, y, test, model_name, rmsle=None):
    model.fit(train, y)
    prediction = model.predict(test)
    prediction = np.expm1(prediction)
    data_dir = '/content/drive/MyDrive/아이펠/풀잎스쿨/data/kaggle-kakr-housing-data/data'
    submission_path = join(data_dir, 'sample_submission.csv')
    submission = pd.read_csv(submission_path)
    submission['price'] = prediction
    submission_csv_path = '{}/submission_{}_RMSLE_{}.csv'.format(data_dir, model_name, rmsle)
    submission.to_csv(submission_csv_path, index=False)
    print('{} saved!'.format(submission_csv_path))

# %%
save_submission(model_1, train, y, test, 'GradientBoostingRegressor', rmsle='0.191645')
# Out:
# /content/drive/MyDrive/아이펠/풀잎스쿨/data/kaggle-kakr-housing-data/data/submission_GradientBoostingRegressor_RMSLE_0.191645.csv saved!

# %% [markdown]
# ### 2. XGBRegressor

# %%
model_2 = XGBRegressor(random_state=random_state)

# %%
my_GridSearch(model_2, train, y, param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [12:20:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#    max_depth  n_estimators     score     RMSLE
# 3          5            50 -0.042205  0.205437
# 1          1            50 -0.067517  0.259840
# 2          5            20 -2.363931  1.537508
# 0          1            20 -2.398704  1.548775

# %%
model_2 = XGBRegressor(max_depth=5, n_estimators=50, random_state=random_state)

# %%
save_submission(model_2, train, y, test, 'XGBRegressor', rmsle='0.205437')
# Out:
# [12:20:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /content/drive/MyDrive/아이펠/풀잎스쿨/data/kaggle-kakr-housing-data/data/submission_XGBRegressor_RMSLE_0.205437.csv saved!

# %% [markdown]
# ###3. RandomForestRegressor

# %%
model_3 = RandomForestRegressor(random_state=random_state)

# %%
my_GridSearch(model_3, train, y, param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
#    max_depth  n_estimators     score     RMSLE
# 3          5            50 -0.052074  0.228197
# 2          5            20 -0.052397  0.228904
# 1          1            50 -0.144639  0.380314
# 0          1            20 -0.144691  0.380383

# %%
model_3 = RandomForestRegressor(max_depth=5, n_estimators=50, random_state=random_state)

# %%
save_submission(model_3, train, y, test, 'RandomForestRegressor', rmsle='0.228197')
# Out:
# /content/drive/MyDrive/아이펠/풀잎스쿨/data/kaggle-kakr-housing-data/data/submission_RandomForestRegressor_RMSLE_0.228197.csv saved!

# %% [markdown]
# ### 4. HistGradientBoostingRegressor

# %%
model_4 = HistGradientBoostingRegressor(random_state=random_state)

# %%
my_GridSearch(model_4, train, y, param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/joblib/externals/loky/process_executor.py", line 436, in _process_worker
#     r = call_item()
#   File "/usr/local/lib/python3.7/dist-packages/joblib/externals/loky/process_executor.py", line 288, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/usr/local/lib/python3.7/dist-packages/joblib/parallel.py", line 263, in <listcomp>
# ...

# %% [markdown]
# ### 5. LGBMRegressor

# %%
model_5 = LGBMRegressor(random_state=random_state)

# %%
my_GridSearch(model_5, train, y, param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
#    max_depth  n_estimators     score     RMSLE
# 3          5            50 -0.036588  0.191280
# 2          5            20 -0.045119  0.212412
# 1          1            50 -0.063284  0.251564
# 0          1            20 -0.097547  0.312326

# %%
model_5 = LGBMRegressor(max_depth=5, n_estimators=50, random_state=random_state)

# %%
save_submission(model_5, train, y, test, 'LGBMRegressor', rmsle='0.191280')
# Out:
# /content/drive/MyDrive/아이펠/풀잎스쿨/data/kaggle-kakr-housing-data/data/submission_LGBMRegressor_RMSLE_0.191280.csv saved!

# %% [markdown]
# ## ✓ Average Blending
# 여러 가지 모델의 결과를 산술평균하여 블렌딩 모델을 만들겠습니다.

# %%
models = [{'model':model_1, 'name':'GradientBoosting'}, {'model':model_2, 'name':'XGBoost'},
          {'model':model_3, 'name':'RandomForest'}, {'model':model_5, 'name':'LightGBM'}, ]

# %% [markdown]
# ## **✓ Cross Validation**
#
# 교차 검증을 통해 모델의 성능을 간단히 평가하겠습니다.

# %%
def get_cv_score(models):
    kfold = KFold(n_splits=5).get_n_splits(train.values)
    for m in models:
        CV_score = np.mean(cross_val_score(m['model'], X=train.values, y=y, cv=kfold))
        print(f"Model: {m['name']}, CV score:{CV_score:.4f}")

# %%
get_cv_score(models)
# Out:
# Model: GradientBoosting, CV score:0.8354
# [12:21:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:21:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:21:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:21:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:21:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Model: XGBoost, CV score:0.8105
# Model: RandomForest, CV score:0.7688
# Model: LightGBM, CV score:0.8353

# %%
def AveragingBlending(models, x, y, sub_x):
    for m in models : 
        m['model'].fit(train.values, y)
    
    predictions = np.column_stack([m['model'].predict(test.values) for m in models])
    return np.mean(predictions, axis=1)

# %%
y_pred = AveragingBlending(models, train, y, test)
print(len(y_pred))
y_pred
# Out:
# [12:21:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 6468
# array([13.10561325, 12.7997106 , 14.04382252, ..., 12.90960586,
#        12.75562576, 12.94852149])

# %%
data_dir = '/content/drive/MyDrive/아이펠/풀잎스쿨/data/kaggle-kakr-housing-data/data'
submission_path = join(data_dir, 'sample_submission.csv')
submission = pd.read_csv(submission_path)
submission['price'] = y_pred
submission_csv_path = '{}/submission_Ensemble_SSona.csv'.format(data_dir)
submission.to_csv(submission_csv_path, index=False)

# %% [markdown]
# # 회고

# %% [markdown]
# ## 캐글 성적
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 이번 프로젝트에서 어려웠던 점

# %% [markdown]
# **1) 변수 혼동**
#
# `train_y`의 경우, log 변형을 안 한 것이 y라고 생각했는데 아니어서 혼선이 생김
#
# <br>
#
# **2) 앙상블 시도 실패**
#
# 그리드 탐색을 한 뒤에도 성능이 좋아지지 않아서 그리드 탐색을 적용한 모델로 앙상블을 시도해 보았으나 폭망

# %% [markdown]
# ## 프로젝트를 진행하면서 알아낸 점 혹은 아직 모호한 점

# %% [markdown]
# 앙상블이 왜 저렇게까지 실패했는지 모르겠다. 더 나은 점수를 얻으려고 시도해본 것인데....

# %% [markdown]
# ## 루브릭 평가 지표를 맞추기 위해 시도한 것들
#
# > 1. 캐글 데이터분석 전과정이 성공적으로 진행되었는가?<br>
# (데이터 전처리, 모델학습, 예측의 전체 과정을 거쳐 캐글 submission까지 진행되었다.)<br><br>
# - 완료함
#
# > 2. 전처리, 학습과정 및 결과에 대한 설명이 시각화를 포함하여 체계적으로 진행되었는가?<br>
# (제출된 노트북이 캐글 커널로 사용될 수 있을 만큼 전처리, 학습, 최적화 진행 과정이 체계적으로 기술되었다.)<br><br>
# - 잘 했다고 생각함
#
# > 3. 회귀모델 예측정확도가 기준 이상 높게 나왔는가?<br>
# (다양한 피처 엔지니어링과 하이퍼 파라미터 튜닝 등의 최적화 기법을 통해 캐글 리더보드의 Private score 기준 110000 이하의 점수를 얻었다.)<br><br>
# - 그리드 탐색을 완료한 모델로 앙상블 모델을 만들었으나 상상을 초월한 점수를 내며 망했다.

# %% [markdown]
# ## 만약에 루브릭 평가 관련 지표를 달성 하지 못했을 때, 이유에 관한 추정

# %% [markdown]
# 1) 너무 많은 컬럼과 이상치를 제거하여 데이터의 대표성이 떨어짐.
#
# 2) 왜인지 모르겠으나, 앙상블이 심하게 곤두박질

# %% [markdown]
# ## 자기 다짐

# %% [markdown]
# 헷갈리고 어려웠다.
